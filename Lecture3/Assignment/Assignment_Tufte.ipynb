# %% [markdown]
# # Assignment : Tufte Graph

# %%
# ignore unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Multiple graphs in one figure

# %%
# load libraries
import os
import numpy as np
from matplotlib import rc
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec

# generate fake data
x = np.arange(0, 10, 1) 
y0 = np.square(x)
y1 = np.sqrt(x)
y2 = 2 + x

# %%
# create multiple figures using 'gridspec' library 
# https://matplotlib.org/stable/api/_as_gen/matplotlib.gridspec.GridSpec.html

# %%
# Export the plot to your local folder
# Out:
# '/Users/kepco/Documents/2023 UK/(Lecture) Data Visualization/My slides/Session3/test_plot.pdf'

# %% [markdown]
# ### 2. Tufte scatter

# %% [markdown]
# #### 2.1 How to dismanle the task
#
# **What is the procedure to draw it?**
#
# 1. Create a figure with four plots (2 x 2)
# 2. Change the grid space between the plots
# 3. Plot three scatter plots (KEY PART)
# 4. Hide the unnecessary axes
# 5. Add the dashed line
# 6. Add the text
#
# **What is the problem we might meet?**
#
# 1. How to create the plot like the left one and the bottom one?
# 2. How to add the text in the plot?
# 3. How to set the space between the plots?

# %%
# aesthetics settings
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=10)

# %%
# generate the fake data
np.random.seed(111) # fix the seed to ensure reproducibility
n = 30
x = np.random.randn(n)
y = 10 + x * (1+ np.random.randn(n))

# %%
# create figure
fig = plt.figure(figsize=(5, 5))

# Step 1 and Step 2
# parition the figure into 4 subplots with 'gridspec'

# %%
# Step 1 and Step 2
# create figure

# ---------------------------------------------------------------------------------------
# Step 3 and Step 4
#(hint1) First plot : univariate distribution of y

#(hint2) Second plot : univariate distribution of x

#(hint3) Third plot : Scatter diagram
# Out:
# /var/folders/8b/slvdhz2n0jngxwl0lkwvg_jh0000gn/T/ipykernel_81379/837062550.py:38: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Step 1 and Step 2



# ---------------------------------------------------------------------------------------
# Step 3 and Step 4

# ---------------------------------------------------------------------------------------
# Step 5 and Step 6

# vertical reference line

# horizontal reference line

# pick-up one data point to emphasize, add reference lines and textbox
# Out:
# /Users/tireisas/miniconda3/envs/dbs/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /var/folders/75/jx2xyqnd3k74bnk7xc0ps4w80000gn/T/ipykernel_11591/3260173907.py:67: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### 3. Stacked histogram

# %%
# %%  matplotlib viz setup
# %matplotlib inline

# %% fake data
'''
Simulate three random variables drawn from different distributions
'''
np.random.seed(111) # fix the seed to ensure reproducibility
x = np.random.normal(loc=-1, scale=0.75, size=1000)
y = np.random.normal(loc=0, scale=1, size=1000)
z = np.random.normal(loc=1, scale=0.5, size=1000)

# %%
# create figure
# Out:
# /var/folders/8b/slvdhz2n0jngxwl0lkwvg_jh0000gn/T/ipykernel_95786/194519463.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-bright')

# %%
# if you want to plot tranparent histogram
# %matplotlib inline
# Out:
# /var/folders/8b/slvdhz2n0jngxwl0lkwvg_jh0000gn/T/ipykernel_95786/674830148.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### 4. Cumulative step histograms

# %% [markdown]
# #### Hint : cumulative histogram = PDF(Probability Density Function)
# ![nn](pdf.png)

# %%
# cumulative step histogram
plt.style.use('seaborn-bright')
rc('font',**{'family':'sans-serif','sans-serif':['Avant Garde']})
rc('text', usetex=True)

# %% fake data
np.random.seed(19680801)
mu = 2.5
sigma = 4
n_bins = 50
x = np.random.normal(mu, sigma, size=1000)

# %% visualization


# add a line showing the expected distribution.(PDF: Probability Distribution Function)


# Convert PDF to CDF (Cumulative Distribution Function) 

# Normalize the distribution between 0 and 1

# overlay a reversed cumulative histogram

# %% [markdown]
# ### 5. Tufte's Bar chart

# %%
# fake data

categories = ['A', 'B', 'C', 'D']
counts = [4, 2, 6, 8]

# visualization (Spines: https://matplotlib.org/stable/api/spines_api.html)

#(hint) hide the right and top spines

# %% [markdown]
# ### 6. Produce multiple plots in bulk

# %%
# fake data
from random import seed

np.random.seed(123)

names = locals()
for i in range(16):
    names[f'x_{i+1}'] = np.random.normal(loc=i, scale=1, size=100)

# %% [markdown]
# The most straightforward way to produce multiple plots is to plot them one by one.

# %%
# visualization
fig  = plt.figure(figsize=(16,16))

# %% [markdown]
# Alternatively, we can use `for loop` to produce the plots in bulk. In this case, if we want to change the color of the plots, we just need to change the color in the `for loop` once.

# %%
# visualization
fig = plt.figure(figsize=(16, 16), frameon=True)
